# %%
import openai
import os
import json
import re
import pandas as pd
from datetime import datetime
from openai import OpenAI

# %%
from util_functions import get_completion_from_messages, extract_json_from_response 
from util_functions import retrieve_df_list_from_csv, parse_raw_csv, assign_category_and_subcategory
# Out:
# /Users/jiamingpei/Desktop/Projects/gptFinance/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
from dataframe_configs import log_filename, log_schema_types, log_schema_cols, log_date_cols

# %%
client = OpenAI(
    # This is the default and can be omitted
    api_key=os.environ.get("OPENAI_API_KEY"),
)

# %%
file_list = retrieve_df_list_from_csv()
# Out:
# File 1: Date range.CSV loaded with Status         2
# Date           2
# Description    2
# Debit          1
# Credit         1
# dtype: int64 records
# File 2: DFS-Search-20240923.csv loaded with Trans. Date    4
# Post Date      4
# Description    4
# Amount         4
# Category       4
# dtype: int64 records
# File 4: Chase4739_Activity20240901_20240915_20240924.CSV loaded with Transaction Date    18
# Post Date           18
# Description         18
# Category            17
# Type                18
# Amount              18
# Memo                 0
# dtype: int64 records
# File 5: Credit Card - 0283_09-01-2024_09-15-2024.csv loaded with Date           6
# Transaction    6
# Name           6
# Memo           6
# Amount         6
# dtype: int64 records
# File 6: CreditCard1.csv loaded with 09/13/2024          3
# 98.55               3
# *                   3
# Unnamed: 3          0
# Bill Pay Payment    3
# dtype: int64 records

# %%
aggregate_book = parse_raw_csv(client, file_list)

# %%
category_map = assign_category_and_subcategory(client, aggregate_book)

# %%
cate_book = pd.DataFrame.from_records(category_map)
pre_audit_df = cate_book.sort_values("Date").reset_index(drop=True)
pre_audit_df.insert(0, "ID", pre_audit_df.index)
pre_audit_df['Date'] = pd.to_datetime(pre_audit_df['Date'])
pre_audit_df.insert(2, "Year", pre_audit_df['Date'].dt.year)
pre_audit_df.insert(3, "Month", pre_audit_df['Date'].dt.month)


pre_audit_output = pre_audit_df.copy()
pre_audit_output['Note'] = ""

if 'audit.csv' not in os.listdir(os.path.join(os.getcwd(), "output")):
    pre_audit_output.to_csv("output/audit.csv", index=False)
    print('Audit data saved.')
else:
    print('audit.csv already exist. Not saving a new copy.')

pre_audit_df = pre_audit_df.astype(log_schema_types)
pre_audit_df
# Out:
# Audit data saved.
#     ID       Date  Year  Month                                 Merchant  \
# 0    0 2024-08-30  2024      8                    SHELL OIL 10008333006
# 1    1 2024-09-01  2024      9        SQ *THE KEBAB SHOP SANTA CLARA CA
# 2    2 2024-09-02  2024      9              TAIWAN PORRIDGE MILPITAS CA
# 3    3 2024-09-02  2024      9              BILTPROTECT RENT ACH CREDIT
# 4    4 2024-09-03  2024      9               99 RANCH #1766 MILPITAS CA
# 5    5 2024-09-03  2024      9                     YANG GUO FU MALATANG
# 6    6 2024-09-04  2024      9  ATT*BILL PAYMENT       800-288-2020  TX
# 7    7 2024-09-04  2024      9  NETFLIX.COM            NETFLIX.COM   CA
# 8    8 2024-09-05  2024      9                   PANERA BREAD #204481 O
# 30   356.00  Entertainment         Entertainment
# 31    44.51    Consumables               Grocery
# 32    69.67    Consumables                Dining

# %%
"""
After manual audit
"""

audit_df = pd.read_csv(os.path.join(os.getcwd(), 'output/audit.csv'))
audit_df["ID"] = audit_df.index
audit_df['Date'] = pd.to_datetime(audit_df['Date'])
audit_df['Year'] = audit_df['Date'].dt.year
audit_df['Month'] = audit_df['Date'].dt.month
audit_df
# Out:
#     ID       Date  Year  Month                                 Merchant  \
# 0    0 2024-08-30  2024      8                    SHELL OIL 10008333006
# 1    1 2024-09-01  2024      9        SQ *THE KEBAB SHOP SANTA CLARA CA
# 2    2 2024-09-02  2024      9              TAIWAN PORRIDGE MILPITAS CA
# 3    3 2024-09-02  2024      9              TAIWAN PORRIDGE MILPITAS CA
# 4    4 2024-09-03  2024      9               99 RANCH #1766 MILPITAS CA
# 5    5 2024-09-03  2024      9                     YANG GUO FU MALATANG
# 6    6 2024-09-03  2024      9                     YANG GUO FU MALATANG
# 7    7 2024-09-04  2024      9  ATT*BILL PAYMENT       800-288-2020  TX
# 8    8 2024-09-04  2024      9  NETFLIX.COM            NETFLIX.COM   CA
# 9    9 2024-09-05  2024      9                   PANERA BREAD #204481 O
# 10  10 2024-09-06  2024      9            TRADER JOE S #229 MILPITAS CA
# 11  11 2024-09-06  2024      9                            CHIPOTLE 2149
# 12  12 2024-09-06  2024      9                   MILPITAS SGD TOFU HOUS
# 13  13 2024-09-07  2024      9                     Curry Hyuga - RETAIL
# 14  14 2024-09-07  2024      9                     Curry Hyuga - RETAIL
# 15  15 2024-09-08  2024      9                   NEW CHINA FOODS MILLBR
# 16  16 2024-09-08  2024      9                   NEW CHINA FOODS MILLBR
# 17  17 2024-09-09  2024      9  CITY OF BURLINGAME-PAR BURLINGAME    CA
# 18  18 2024-09-09  2024      9                           IZAKAYA GINJI.
# 19  19 2024-09-10  2024      9                        PANERA EGIFT CARD
# 20  20 2024-09-10  2024      9  FEDEX OFFIC51000051052 MENLO PARK    CA
# 21  21 2024-09-10  2024      9                   PANERA BREAD #204481 O
# 22  22 2024-09-11  2024      9  CVS/PHARMACY #06867    LAS VEGAS     NV
# 23  23 2024-09-12  2024      9                              HUNAN MIFEN
# 24  24 2024-09-12  2024      9                              HUNAN MIFEN
# 25  25 2024-09-12  2024      9                     HUDSON-DUNKIN ST1599
# 26  26 2024-09-13  2024      9                        SQ *SEN DAI SUSHI
# 27  27 2024-09-13  2024      9               VAIL SKI PASS & RC VAIL CO
# 28  28 2024-09-14  2024      9          H MART SAN JOSE LLC SAN JOSE CA
# 29  29 2024-09-15  2024      9                         TST*THE TABLE-CA
# 30  30 2024-09-15  2024      9                         TST*THE TABLE-CA
#
#     Amount       Category         Subcategory       Note
# 0    66.68         Travel                Auto        NaN
# 1    22.97    Consumables              Dining        NaN
# 2    28.28    Consumables              Dining        NaN
# 3    28.28    Consumables              Dining     Dating
# 4    25.59    Consumables             Grocery        NaN
# 5    19.19    Consumables              Dining        NaN
# 6    19.19    Consumables              Dining     Dating
# 7    65.35           Home           Utilities        NaN
# 8    22.99   Subscription        Subscription        NaN
# 9     6.76    Consumables              Dining        NaN
# 10   24.13    Consumables             Grocery        NaN
# 11   14.90    Consumables              Dining        NaN
# 12   30.00    Consumables              Dining        NaN
# 13   22.75    Consumables              Dining        NaN
# 14   22.75    Consumables              Dining     Dating
# 15   36.12    Consumables              Dining        NaN
# 16   36.12    Consumables              Dining     Dating
# 17    1.00         Travel      Transportation        NaN
# 18   50.00    Consumables              Dining        NaN
# 19   40.00    Consumables              Dining        NaN
# 20    0.72         Others       Miscellaneous        NaN
# 21   19.23    Consumables              Dining        NaN
# 22   14.38    Consumables  Household Supplies        NaN
# 23   25.65    Consumables              Dining        NaN
# 24   25.65    Consumables              Dining     Dating
# 25    5.95    Consumables              Dining        NaN
# 26   34.82    Consumables              Dining        NaN
# 27  356.00  Entertainment       Entertainment  Epic Pass
# 28   44.51    Consumables             Grocery        NaN
# 29   34.84    Consumables              Dining        NaN
# 30   34.84    Consumables              Dining     Dating

# %%
audit_df.to_csv("output/audit.csv", index=False)

# %%
# if log_filename not in os.listdir(os.path.join(os.getcwd(), 'output')):
#     empty_df = pd.DataFrame({col: pd.Series(dtype=dtype) for col, dtype in log_schema_types.items()})
#     for c in log_schema_cols:
#         if c not in empty_df.columns:
#             empty_df[c] = ""
#     empty_df = empty_df[log_schema_cols]
#     empty_df.to_csv(f"output/{log_filename}", index=False)

# old_logs = pd.read_csv(f"output/{log_filename}", dtype=log_schema_types, parse_dates=list(log_date_cols.keys()))

# audit_df['LogDate'] = datetime.utcnow().strftime('%Y-%m-%d %H:%M:%S')

# for k, v in log_date_cols.items():
#     audit_df[k] = pd.to_datetime(audit_df[k], format=v)

# new_logs = pd.concat([old_logs, audit_df])
# new_logs = new_logs.sort_values(['LogDate', 'Date']).reset_index(drop=True)
# new_logs["ID"] = new_logs.index

# threshold = 5
# if len(old_logs) > 0:
#     day_diff = (audit_df['LogDate'].max() - old_logs['LogDate'].max()).days
# else:
#     day_diff = threshold
# if day_diff < threshold:
#     user_res = input(f"The most recent log update is less than {day_diff} days. Do you want to update logs anyways?(y/n)")
#     if user_res.lower() == 'y':
#         new_logs.to_csv(f"output/{log_filename}", index=False)
#         print(f"Update successful. {len(audit_df)} new records inserted to the log.")
#     else:
#         print("Update aborted. No new records inserted to the log.")
# else:
#     new_logs.to_csv(f"output/{log_filename}", index=False)
#     print(f"Update successful. {len(audit_df)} new records inserted to the log.")
# Out:
# The most recent log update is less than 0 days. Do you want to update logs anyways?(y/n) y
# Update successful. 90 new records inserted to the log.
